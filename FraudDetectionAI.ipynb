# %% [markdown]
# # Fraud Detection in Electricity and Gas Consumption Challenge
#
# File name: FraudDetectionAI.ipynb
#
# Author: kogni7
#
# Date: October/November 2021
#
# ## Contents
# * 1 Preparation
# * 2 Data
# * 3 Training
# * 4 Prediction and Submission
#
# This notebook uses only the data sets provided by ZINDI. These data sets contain information about clients. These are the only used features in this notebook. The task is to classify whether there is a fraud or not.
#
# The file system for this project is:
# * FraudDetectionAI (root)
#     * FraudDetectionAI.ipynb (this notebook)
#     * Data
#         * client_test.csv
#         * client_train.csv
#         * invoice_test.csv
#         * invoice_train.csv
#         * SampleSubmission.csv
#     * Submission
#         * 1 - x: Submission directories named by the version number
#             * submission.csv
#
# This jupyter notebook runs in Google Colab without special configuration. GPU is disabled.
#
# This notebook uses the julia version of XGBoost.

# %% [markdown]
# ## 1 Preparation
# Load data from Google Drive!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Install julia kernel!

# %%
url = 'https://julialang-s3.julialang.org/bin/linux/x64/1.6/julia-1.6.2-linux-x86_64.tar.gz'
!wget -O- $url | tar xz -C /usr/local --strip-components 1
!julia -e 'using Pkg; pkg"add IJulia; precompile;"'
# Out:
# --2021-11-09 16:21:15--  https://julialang-s3.julialang.org/bin/linux/x64/1.6/julia-1.6.2-linux-x86_64.tar.gz
# Resolving julialang-s3.julialang.org (julialang-s3.julialang.org)... 151.101.2.49, 151.101.66.49, 151.101.130.49, ...
# Connecting to julialang-s3.julialang.org (julialang-s3.julialang.org)|151.101.2.49|:443... connected.
# HTTP request sent, awaiting response... 302 gce internal redirect trigger
# Location: https://storage.googleapis.com/julialang2/bin/linux/x64/1.6/julia-1.6.2-linux-x86_64.tar.gz [following]
# --2021-11-09 16:21:15--  https://storage.googleapis.com/julialang2/bin/linux/x64/1.6/julia-1.6.2-linux-x86_64.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.203.128, 74.125.204.128, 64.233.189.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.203.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 112946671 (108M) [application/x-tar]
# Saving to: ‘STDOUT’
#
# -                    89%[================>   ]  96.00M  18.7MB/s    eta 1s

# %% [markdown]
# Reload tab for proper use of the julia kernel!

# %% [markdown]
# ### Installation

# %%
import Pkg
Pkg.add("DataFrames")
Pkg.add("CSV")
Pkg.add("StatsBase")
Pkg.add("MLLabelUtils")
Pkg.add("MLJ")
Pkg.add("XGBoost")
Pkg.add("MLJXGBoostInterface")
Pkg.add("Tables")
Pkg.add("FreqTables")
# Out:
#     Updating registry at `~/.julia/registries/General`
#    Resolving package versions...
#    Installed DataValueInterfaces ───────── v1.0.0
#    Installed Crayons ───────────────────── v4.0.4
#    Installed Formatting ────────────────── v0.4.2
#    Installed Compat ────────────────────── v3.40.0
#    Installed SortingAlgorithms ─────────── v1.0.1
#    Installed OrderedCollections ────────── v1.4.1
#    Installed DataFrames ────────────────── v1.2.2
#    Installed IteratorInterfaceExtensions ─ v1.0.0
#    Installed DataAPI ───────────────────── v1.9.0
#    Installed InvertedIndices ───────────── v1.1.0
#    Installed Tables ────────────────────── v1.6.0
#    Installed DataStructures ────────────── v0.18.10
#    Installed PooledArrays ──────────────── v1.3.0
#    Installed Reexport ──────────────────── v1.2.2
#    Installed PrettyTables ──────────────── v1.2.3
#    Installed TableTraits ───────────────── v1.0.1
#    Installed Missings ──────────────────── v1.0.2
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [a93c6f00] + DataFrames v1.2.2
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [34da2185] + Compat v3.40.0
#   [a8cc5b0e] + Crayons v4.0.4
#   [9a962f9c] + DataAPI v1.9.0
#   [a93c6f00] + DataFrames v1.2.2
#   [864edb3b] + DataStructures v0.18.10
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [59287772] + Formatting v0.4.2
#   [41ab1584] + InvertedIndices v1.1.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [e1d29d7a] + Missings v1.0.2
#   [bac558e1] + OrderedCollections v1.4.1
#   [2dfb63ee] + PooledArrays v1.3.0
#   [08abe8d2] + PrettyTables v1.2.3
#   [189a3867] + Reexport v1.2.2
#   [a2af1166] + SortingAlgorithms v1.0.1
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.6.0
#   [8bb1440f] + DelimitedFiles
#   [8ba89e20] + Distributed
#   [9fa8497b] + Future
#   [37e2e46d] + LinearAlgebra
#   [1a1011a3] + SharedArrays
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
# Precompiling project...
#   ✓ DataAPI
#   ✓ OrderedCollections
#   ✓ Reexport
#   ✓ Crayons
#   ✓ Compat
#   ✓ DataValueInterfaces
#   ✓ InvertedIndices
#   ✓ IteratorInterfaceExtensions
#   ✓ Formatting
#   ✓ PooledArrays
#   ✓ Missings
#   ✓ TableTraits
#   ✓ Tables
#   ✓ DataStructures
#   ✓ SortingAlgorithms
#   ✓ PrettyTables
#   ✓ DataFrames
#   17 dependencies successfully precompiled in 44 seconds (15 already precompiled)
#    Resolving package versions...
#    Installed CodecZlib ────────── v0.7.0
#    Installed InlineStrings ────── v1.0.1
#    Installed WeakRefStrings ───── v1.4.1
#    Installed FilePathsBase ────── v0.9.14
#    Installed TranscodingStreams ─ v0.9.6
#    Installed SentinelArrays ───── v1.3.8
#    Installed CSV ──────────────── v0.9.10
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [336ed68f] + CSV v0.9.10
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [336ed68f] + CSV v0.9.10
#   [944b1d66] + CodecZlib v0.7.0
#   [48062228] + FilePathsBase v0.9.14
#   [842dd82b] + InlineStrings v1.0.1
#   [91c51154] + SentinelArrays v1.3.8
#   [3bb67fe8] + TranscodingStreams v0.9.6
#   [ea10d353] + WeakRefStrings v1.4.1
# Precompiling project...
#   ✓ InlineStrings
#   ✓ TranscodingStreams
#   ✓ FilePathsBase
#   ✓ CodecZlib
#   ✓ SentinelArrays
#   ✓ WeakRefStrings
#   ✓ CSV
#   7 dependencies successfully precompiled in 10 seconds (32 already precompiled)
#    Resolving package versions...
#    Installed DocStringExtensions ─ v0.8.6
#    Installed LogExpFunctions ───── v0.3.5
#    Installed StatsAPI ──────────── v1.0.0
#    Installed IrrationalConstants ─ v0.1.1
#    Installed InverseFunctions ──── v0.1.2
#    Installed ChangesOfVariables ── v0.1.1
#    Installed StatsBase ─────────── v0.33.12
#    Installed ChainRulesCore ────── v1.11.1
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [2913bbd2] + StatsBase v0.33.12
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [d360d2e6] + ChainRulesCore v1.11.1
#   [9e997f8a] + ChangesOfVariables v0.1.1
#   [ffbed154] + DocStringExtensions v0.8.6
#   [3587e190] + InverseFunctions v0.1.2
#   [92d709cd] + IrrationalConstants v0.1.1
#   [2ab3a3ac] + LogExpFunctions v0.3.5
#   [82ae8749] + StatsAPI v1.0.0
#   [2913bbd2] + StatsBase v0.33.12
# Precompiling project...
#   ✓ InverseFunctions
#   ✓ DocStringExtensions
#   ✓ StatsAPI
#   ✓ ChangesOfVariables
#   ✓ IrrationalConstants
#   ✓ ChainRulesCore
#   ✓ LogExpFunctions
#   ✓ StatsBase
#   8 dependencies successfully precompiled in 8 seconds (39 already precompiled)
#    Resolving package versions...
#    Installed MappedArrays ─ v0.4.1
#    Installed LearnBase ──── v0.4.1
#    Installed MLLabelUtils ─ v0.5.6
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [66a33bbf] + MLLabelUtils v0.5.6
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [7f8f8fb0] + LearnBase v0.4.1
#   [66a33bbf] + MLLabelUtils v0.5.6
#   [dbb5928d] + MappedArrays v0.4.1
# Precompiling project...
#   ✓ MappedArrays
#   ✓ LearnBase
#   ✓ MLLabelUtils
#   3 dependencies successfully precompiled in 2 seconds (47 already precompiled)
#    Resolving package versions...
#    Installed OpenSpecFun_jll ──────── v0.5.5+0
#    Installed StableRNGs ───────────── v1.0.0
#    Installed ARFFFiles ────────────── v1.4.0
#    Installed BSON ─────────────────── v0.3.4
#    Installed Rmath ────────────────── v0.7.0
#    Installed QuadGK ───────────────── v2.4.2
#    Installed ExprTools ────────────── v0.1.6
#    Installed MLJModelInterface ────── v1.3.3
#    Installed UnPack ───────────────── v1.0.2
#    Installed StatsFuns ────────────── v0.9.12
#    Installed Requires ─────────────── v1.1.3
#    Installed ScientificTypes ──────── v2.3.3
#    Installed JLSO ─────────────────── v2.6.0
#    Installed MLJIteration ─────────── v0.3.3
#    Installed MLJEnsembles ─────────── v0.1.2
#    Installed MLJ ──────────────────── v0.16.11
#    Installed OpenML ───────────────── v0.1.1
#    Installed ComputationalResources ─ v0.3.2
#    Installed URIs ─────────────────── v1.3.0
#    Installed Memento ──────────────── v1.2.0
#    Installed LossFunctions ────────── v0.7.2
#    Installed IterationControl ─────── v0.4.0
#    Installed Mocking ──────────────── v0.7.3
#    Installed ProgressMeter ────────── v1.7.1
#    Installed PDMats ───────────────── v0.11.3
#    Installed Distances ────────────── v0.10.6
#    Installed ColorTypes ───────────── v0.11.0
#    Installed FixedPointNumbers ────── v0.8.4
#    Installed StatisticalTraits ────── v2.1.0
#    Installed IniFile ──────────────── v0.5.0
#    Installed ScientificTypesBase ──── v2.3.0
#    Installed MLJSerialization ─────── v1.1.2
#    Installed Parameters ───────────── v0.12.3
#    Installed FillArrays ───────────── v0.12.7
#    Installed MLJTuning ────────────── v0.6.14
#    Installed SpecialFunctions ─────── v1.8.1
#    Installed LatinHypercubeSampling ─ v1.8.0
#    Installed EarlyStopping ────────── v0.1.9
#    Installed Rmath_jll ────────────── v0.3.0+0
#    Installed HTTP ─────────────────── v0.9.16
#    Installed MLJModels ────────────── v0.14.12
#    Installed RecipesBase ──────────── v1.1.2
#    Installed Distributions ────────── v0.25.24
#    Installed TimeZones ────────────── v1.6.2
#    Installed MLJBase ──────────────── v0.18.24
#    Installed Syslogs ──────────────── v0.3.0
#    Installed CategoricalArrays ────── v0.10.2
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [add582a8] + MLJ v0.16.11
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [da404889] + ARFFFiles v1.4.0
#   [fbb218c0] + BSON v0.3.4
#   [324d7699] + CategoricalArrays v0.10.2
#   [3da002f7] + ColorTypes v0.11.0
#   [ed09eef8] + ComputationalResources v0.3.2
#   [b4f34e82] + Distances v0.10.6
#   [31c24e10] + Distributions v0.25.24
#   [792122b4] + EarlyStopping v0.1.9
#   [e2ba6199] + ExprTools v0.1.6
#   [1a297f60] + FillArrays v0.12.7
#   [53c48c17] + FixedPointNumbers v0.8.4
#   [cd3eb016] + HTTP v0.9.16
#   [83e8ac13] + IniFile v0.5.0
#   [b3c1a2ee] + IterationControl v0.4.0
#   [9da8a3cd] + JLSO v2.6.0
#   [a5e1c1ea] + LatinHypercubeSampling v1.8.0
#   [30fc2ffe] + LossFunctions v0.7.2
#   [add582a8] + MLJ v0.16.11
#   [a7f614a8] + MLJBase v0.18.24
#   [50ed68f4] + MLJEnsembles v0.1.2
#   [614be32b] + MLJIteration v0.3.3
#   [e80e1ace] + MLJModelInterface v1.3.3
#   [d491faf4] + MLJModels v0.14.12
#   [17bed46d] + MLJSerialization v1.1.2
#   [03970b2e] + MLJTuning v0.6.14
#   [f28f55f0] + Memento v1.2.0
#   [78c3b35d] + Mocking v0.7.3
#   [8b6db2d4] + OpenML v0.1.1
#   [90014a1f] + PDMats v0.11.3
#   [d96e819e] + Parameters v0.12.3
#   [92933f4c] + ProgressMeter v1.7.1
#   [1fd47b50] + QuadGK v2.4.2
#   [3cdcf5f2] + RecipesBase v1.1.2
#   [ae029012] + Requires v1.1.3
#   [79098fc4] + Rmath v0.7.0
#   [321657f4] + ScientificTypes v2.3.3
#   [30f210dd] + ScientificTypesBase v2.3.0
#   [276daf66] + SpecialFunctions v1.8.1
#   [860ef19b] + StableRNGs v1.0.0
#   [64bff920] + StatisticalTraits v2.1.0
#   [4c63d2b9] + StatsFuns v0.9.12
#   [cea106d9] + Syslogs v0.3.0
#   [f269a46b] + TimeZones v1.6.2
#   [5c2747f8] + URIs v1.3.0
#   [3a884ed6] + UnPack v1.0.2
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [f50d1b31] + Rmath_jll v0.3.0+0
#   [4af54fe1] + LazyArtifacts
#   [4607b0f0] + SuiteSparse
#   [e66e0078] + CompilerSupportLibraries_jll
#   [05823500] + OpenLibm_jll
#     Building TimeZones → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/8de32288505b7db196f36d27d7236464ef50dba1/build.log`
# Precompiling project...
#   ✓ StableRNGs
#   ✓ ScientificTypesBase
#   ✓ ComputationalResources
#   ✓ IniFile
#   ✓ URIs
#   ✓ UnPack
#   ✓ BSON
#   ✓ PDMats
#   ✓ FixedPointNumbers
#   ✓ FillArrays
#   ✓ Requires
#   ✓ OpenLibm_jll
#   ✓ EarlyStopping
#   ✓ ProgressMeter
#   ✓ CompilerSupportLibraries_jll
#   ✓ Syslogs
#   ✓ Distances
#   ✓ Rmath_jll
#   ✓ QuadGK
#   ✓ StatisticalTraits
#   ✓ LossFunctions
#   ✓ Parameters
#   ✓ LatinHypercubeSampling
#   ✓ CategoricalArrays
#   ✓ HTTP
#   ✓ IterationControl
#   ✓ OpenSpecFun_jll
#   ✓ Rmath
#   ✓ MLJModelInterface
#   ✓ ARFFFiles
#   ✓ Memento
#   ✓ JLSO
#   ✓ SpecialFunctions
#   ✓ ColorTypes
#   ✓ StatsFuns
#   ✓ Distributions
#   ✓ ScientificTypes
#   ✓ OpenML
#   ✓ MLJBase
#   ✓ MLJTuning
#   ✓ MLJIteration
#   ✓ MLJSerialization
#   ✓ MLJEnsembles
#   ✓ MLJModels
#   ✓ MLJ
#   45 dependencies successfully precompiled in 80 seconds (54 already precompiled)
#    Resolving package versions...
#    Installed XGBoost_jll ─ v1.4.2+0
#    Installed XGBoost ───── v1.1.1
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [009559a3] + XGBoost v1.1.1
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [009559a3] + XGBoost v1.1.1
#   [a5c6f535] + XGBoost_jll v1.4.2+0
# Precompiling project...
#   ✓ XGBoost_jll
#   ✓ XGBoost
#   2 dependencies successfully precompiled in 2 seconds (99 already precompiled)
#    Resolving package versions...
#    Installed MLJXGBoostInterface ─ v0.1.5
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [54119dfa] + MLJXGBoostInterface v0.1.5
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [54119dfa] + MLJXGBoostInterface v0.1.5
# Precompiling project...
#   ✓ MLJXGBoostInterface
#   1 dependency successfully precompiled in 1 seconds (101 already precompiled)
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [bd369af6] + Tables v1.6.0
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`
#    Resolving package versions...
#    Installed FreqTables ──── v0.4.5
#    Installed Combinatorics ─ v1.0.2
#    Installed NamedArrays ─── v0.9.6
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [da1fdf0e] + FreqTables v0.4.5
#     Updating `~/.julia/environments/v1.6/Manifest.toml`
#   [861a8166] + Combinatorics v1.0.2
#   [da1fdf0e] + FreqTables v0.4.5
#   [86f7a689] + NamedArrays v0.9.6
# Precompiling project...
#   ✓ Combinatorics
#   ✓ NamedArrays
#   ✓ FreqTables
#   3 dependencies successfully precompiled in 3 seconds (102 already precompiled)

# %% [markdown]
# ### Seed and Libraries

# %%
import Random
SEED = 42
Random.seed!(SEED)

using DataFrames, CSV
using MLLabelUtils
using Statistics
using StatsBase
using MLJ
using XGBoost
using Tables
using FreqTables

# %% [markdown]
# ### Parameters

# %%
Version = "Version_3"
nfolds = 5
N = 100
# Out:
# 100

# %% [markdown]
# ## 2 Data

# %%
client_train_csv = DataFrame(CSV.File("/content/drive/MyDrive/FraudDetectionAI/Data/client_train.csv"))
invoice_train_csv = DataFrame(CSV.File("/content/drive/MyDrive/FraudDetectionAI/Data/invoice_train.csv"))

client_test_csv = DataFrame(CSV.File("/content/drive/MyDrive/FraudDetectionAI/Data/client_test.csv"))
invoice_test_csv = DataFrame(CSV.File("/content/drive/MyDrive/FraudDetectionAI/Data/invoice_test.csv"))

sample_submission_csv = DataFrame(CSV.File("/content/drive/MyDrive/FraudDetectionAI/Data/SampleSubmission.csv"))

# Remove unnecessary columns
client_train_csv = select!(client_train_csv, Not([:creation_date]))
invoice_train_csv = select!(invoice_train_csv, Not([:invoice_date]))

client_test_csv = select!(client_test_csv, Not([:creation_date]))
invoice_test_csv = select!(invoice_test_csv, Not([:invoice_date]))

# Label encode string columns
invoice_train_csv.counter_type = convertlabel(LabelEnc.Indices, invoice_train_csv.counter_type)
invoice_train_csv.counter_statue = convertlabel(LabelEnc.Indices, invoice_train_csv.counter_statue)

invoice_test_csv.counter_type = convertlabel(LabelEnc.Indices, invoice_test_csv.counter_type)
invoice_test_csv.counter_statue = convertlabel(LabelEnc.Indices, invoice_test_csv.counter_statue)

# Build the mean over the columns in invoice
invoice_train_csv = sort(combine(groupby(invoice_train_csv, :client_id),
                                         :tarif_type=>mean=>:tarif_type,
                                         :counter_number=>mean=>:counter_number,
                                         :counter_statue=>mean=>:counter_statue,
                                         :counter_code=>mean=>:counter_code,
                                         :reading_remarque=>mean=>:reading_remarque,
                                         :counter_coefficient=>mean=>:counter_coefficient,
                                         :consommation_level_1=>mean=>:consommation_level_1,
                                         :consommation_level_2=>mean=>:consommation_level_2,
                                         :consommation_level_3=>mean=>:consommation_level_3,
                                         :consommation_level_4=>mean=>:consommation_level_4,
                                         :old_index=>mean=>:old_index,
                                         :new_index=>mean=>:new_index,
                                         :months_number=>mean=>:months_number,
                                         :counter_type=>mean=>:counter_type,
                                         ), :client_id)

invoice_test_csv = sort(combine(groupby(invoice_test_csv, :client_id),
                                        :tarif_type=>mean=>:tarif_type,
                                        :counter_number=>mean=>:counter_number,
                                        :counter_statue=>mean=>:counter_statue,
                                        :counter_code=>mean=>:counter_code,
                                        :reading_remarque=>mean=>:reading_remarque,
                                        :counter_coefficient=>mean=>:counter_coefficient,
                                        :consommation_level_1=>mean=>:consommation_level_1,
                                        :consommation_level_2=>mean=>:consommation_level_2,
                                        :consommation_level_3=>mean=>:consommation_level_3,
                                        :consommation_level_4=>mean=>:consommation_level_4,
                                        :old_index=>mean=>:old_index,
                                        :new_index=>mean=>:new_index,
                                        :months_number=>mean=>:months_number,
                                        :counter_type=>mean=>:counter_type,
                                        ), :client_id)

# Merge the data frames
train_csv = sort(innerjoin(client_train_csv, invoice_train_csv, on = :client_id), :client_id)
test_csv = sort(innerjoin(client_test_csv, invoice_test_csv, on = :client_id), :client_id)
# Out:
# 58069×18 DataFrame
#    Row │ disrict  client_id          client_catg  region  tarif_type  counter_ ⋯
#        │ Int64    String31           Int64        Int64   Float64     Float64  ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │      62  test_Client_0               11     307     11.0     651208.0 ⋯
#      2 │      69  test_Client_1               11     103     11.0     174760.0
#      3 │      62  test_Client_10              11     310     23.5405       3.4
#      4 │      60  test_Client_100             11     101     25.5          5.8
#      5 │      62  test_Client_1000            11     301     20.8491       1.6 ⋯
#      6 │      62  test_Client_10000           11     304     11.0     639605.0
#      7 │      62  test_Client_10001           11     303     25.3117       3.8
#      8 │      69  test_Client_10002           11     104     29.039        3.7
#      9 │      62  test_Client_10003           11     309     11.0     454471.0 ⋯
#     10 │      69  test_Client_10004           11     107     21.7581       1.6
#     11 │      62  test_Client_10005           11     302     13.0          2.7
#    ⋮   │    ⋮             ⋮               ⋮         ⋮         ⋮              ⋮ ⋱
#  58060 │      62  test_Client_9990            11     371     11.0          2.1
#  58061 │      60  test_Client_9991            11     101     24.5303       3.6 ⋯
#  58062 │      69  test_Client_9992            11     104     25.5      12444.0
#  58063 │      60  test_Client_9993            11     101     25.5          2.6
#  58064 │      69  test_Client_9994            11     104     23.9474       4.4
#  58065 │      63  test_Client_9995            11     399     25.5     736773.0 ⋯
#  58066 │      63  test_Client_9996            11     311     25.5          2.1
#  58067 │      60  test_Client_9997            11     101     21.1864       1.3
#  58068 │      60  test_Client_9998            11     101     11.0          2.1
#  58069 │      69  test_Client_9999            11     104     11.0     869269.0 ⋯
#                                                13 columns and 58048 rows omitted

# %%
# Remove client_id
train_csv = select!(train_csv, Not([:client_id]))
test_csv = select!(test_csv, Not([:client_id]))

describe(train_csv)
# Out:
# 18×7 DataFrame
#  Row │ variable              mean           min         median        max      ⋯
#      │ Symbol                Float64        Real        Float64       Real     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ disrict                  63.5112      60           62.0            69   ⋯
#    2 │ client_catg              11.5125      11           11.0            51
#    3 │ region                  206.16       101          107.0           399
#    4 │ target                    0.0558405    0.0          0.0             1.0
#    5 │ tarif_type               17.1651       9.77778     11.0            45.0 ⋯
#    6 │ counter_number            6.9092e11    0.0          6.69184e5       2.7
#    7 │ counter_statue            1.04486      1.0          1.0            10.0
#    8 │ counter_code            199.547        0.0        203.0           600.0
#    9 │ reading_remarque          7.3988       6.0          7.28571       413.0 ⋯
#   10 │ counter_coefficient       1.00169      0.888889     1.0            50.0
#   11 │ consommation_level_1    432.366        0.0        355.641       99920.0
#   12 │ consommation_level_2    115.334        0.0          4.98718    115683.0
#   13 │ consommation_level_3     27.6342       0.0          0.0         38526.9 ⋯
#   14 │ consommation_level_4     73.098        0.0          0.0         79179.8
#   15 │ old_index             14333.5          0.0       8145.75            1.4
#   16 │ new_index             14958.8          0.0       8674.34            1.5
#   17 │ months_number            33.0146       1.0          4.2             6.0 ⋯
#   18 │ counter_type              1.21224      1.0          1.0             2.0
#                                                                3 columns omitted

# %%
describe(test_csv)
# Out:
# 17×7 DataFrame
#  Row │ variable              mean            min         median        max     ⋯
#      │ Symbol                Float64         Real        Float64       Real    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ disrict                  63.5106       60           62.0           69   ⋯
#    2 │ client_catg              11.5072       11           11.0           51
#    3 │ region                  206.018       101          107.0          399
#    4 │ tarif_type               17.171         9.86207     11.0           45.0
#    5 │ counter_number            7.13907e11    0.0          6.64794e5      2.7 ⋯
#    6 │ counter_statue            1.04316       1.0          1.0            5.0
#    7 │ counter_code            199.964         5.0        203.0          600.0
#    8 │ reading_remarque          7.39764       6.0          7.29167        9.0
#    9 │ counter_coefficient       1.00051       0.929825     1.0           10.0 ⋯
#   10 │ consommation_level_1    434.251         0.0        358.474      57651.0
#   11 │ consommation_level_2    117.842         0.0          5.42667    80717.5
#   12 │ consommation_level_3     27.5828        0.0          0.0        11769.6
#   13 │ consommation_level_4     67.3188        0.0          0.0        44282.5 ⋯
#   14 │ old_index             14501.0           0.0       8288.0            1.1
#   15 │ new_index             15124.3           0.0       8823.69           1.1
#   16 │ months_number            52.0824        1.0          4.2            5.2
#   17 │ counter_type              1.2124        1.0          1.0            2.0 ⋯
#                                                                3 columns omitted

# %%
sort(freqtable(train_csv.target))
# Out:
# 2-element Named Vector{Int64}
# Dim1  │
# ──────┼───────
# 1.0   │   7566
# 0.0   │ 127927

# %%
# Make Data!
labels_xg = train_csv.target
features_xg = select(train_csv, Not([:target]))
labels_xg = coerce(labels_xg, Multiclass)
features_xg = Matrix(features_xg)
features_xg = MLJ.table(features_xg)

features_test_xg = test_csv
features_test_xg = Matrix(features_test_xg)
features_test_xg = MLJ.table(features_test_xg)
# Out:
# Tables.MatrixTable{Matrix{Float64}} with 58069 rows, 17 columns, and schema:
#  :x1   Float64
#  :x2   Float64
#  :x3   Float64
#  :x4   Float64
#  :x5   Float64
#  :x6   Float64
#  :x7   Float64
#  :x8   Float64
#  :x9   Float64
#  :x10  Float64
#  :x11  Float64
#  :x12  Float64
#  :x13  Float64
#  :x14  Float64
#  :x15  Float64
#  :x16  Float64
#  :x17  Float64

# %% [markdown]
# ## 3 Training

# %%
xg = @load XGBoostClassifier
xg = xg()
xg.seed = SEED
xg.num_round = 200

# eta = learning rate in [0, 1]
r1 = range(xg, :(eta), lower=0.01, upper=0.99)

# gamma in [0, ]
r2 = range(xg, :(gamma), lower=0.01, upper=2.5)

# max depth in [1, ]
r3 = range(xg, :(max_depth), lower=1, upper=10)

# min child weight in [0, ]
r4 = range(xg, :(min_child_weight), lower=0.01, upper=0.5)

# subsample in [0, 1]
r5 = range(xg, :(subsample), lower=0.01, upper=0.99)

xg_tune = TunedModel(model=xg, tuning=RandomSearch(rng=SEED), range=[r1, r2, r3, r4, r5], resampling=StratifiedCV(nfolds=nfolds, rng=SEED), measure=auc, n=N);
xg_mach = machine(xg_tune, features_xg, labels_xg)

MLJ.fit!(xg_mach)
report(xg_mach)
# Out:
# ┌ Info: For silent loading, specify `verbosity=0`.
# └ @ Main /root/.julia/packages/MLJModels/4sRmw/src/loading.jl:168
# import MLJXGBoostInterface ✔
# ┌ Info: Training Machine{ProbabilisticTunedModel{RandomSearch,…},…}.
# └ @ MLJBase /root/.julia/packages/MLJBase/u6vLz/src/machines.jl:403
# ┌ Info: Attempting to evaluate 100 models.
# └ @ MLJTuning /root/.julia/packages/MLJTuning/bjRHJ/src/tuned_models.jl:680
# Evaluating over 100 metamodels: 100%[=========================] Time: 4:48:05
# (best_model = XGBoostClassifier,
#  best_history_entry = (model = XGBoostClassifier,
#                        measure = [AreaUnderCurve()],
#                        measurement = Float32[0.84079],
#                        per_fold = Vector{Float32}[[0.83984184, 0.8288561, 0.8446317, 0.84244806, 0.84817255]],),
#  history = NamedTuple{(:model, :measure, :measurement, :per_fold), Tuple{MLJXGBoostInterface.XGBoostClassifier, Vector{AreaUnderCurve}, Vector{Float32}, Vector{Vector{Float32}}}}[(model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.74722403], per_fold = [[0.7459393, 0.74953866, 0.7458044, 0.7425663, 0.7522715]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.79236704], per_fold = [[0.7897958, 0.7840758, 0.7953931, 0.79796326, 0.79460734]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.83155394], per_fold = [[0.8279012, 0.82278943, 0.8366911, 0.83279186, 0.8375961]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.83542794], per_fold = [[0.8318393, 0.82662463, 0.8397806, 0.8360637, 0.84283143]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.66629446], per_fold = [[0.667786, 0.65727353, 0.66995883, 0.67383367, 0.6626202]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.80172443], per_fold = [[0.8089471, 0.78974825, 0.79922754, 0.7981395, 0.81255984]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.8382923], per_fold = [[0.8365509, 0.8302051, 0.8407049, 0.8375682, 0.84643245]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.8320505], per_fold = [[0.8285883, 0.8213861, 0.837132, 0.8362433, 0.83690286]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.7954959], per_fold = [[0.7971178, 0.7831077, 0.79456115, 0.80294985, 0.7997431]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.67337257], per_fold = [[0.68988556, 0.63693875, 0.6980426, 0.6696308, 0.6723651]])  …  (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.7990448], per_fold = [[0.8030935, 0.7871098, 0.80099404, 0.7992452, 0.8047816]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.82713175], per_fold = [[0.8258819, 0.8168143, 0.83184105, 0.82658887, 0.83453274]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.67283523], per_fold = [[0.6689868, 0.67240757, 0.6700405, 0.6824387, 0.6703025]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.8359108], per_fold = [[0.8338216, 0.8264722, 0.838875, 0.8366191, 0.84376574]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.74531996], per_fold = [[0.7514681, 0.732689, 0.7474959, 0.74663234, 0.74831456]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.81177104], per_fold = [[0.81115025, 0.79746675, 0.814154, 0.81692314, 0.8191607]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.66534513], per_fold = [[0.67896974, 0.6622866, 0.67372984, 0.6364619, 0.6752775]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.71940106], per_fold = [[0.72671723, 0.7091411, 0.72180396, 0.7191514, 0.7201919]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.776549], per_fold = [[0.78301144, 0.76834315, 0.7752422, 0.7810761, 0.77507216]]), (model = XGBoostClassifier, measure = [AreaUnderCurve()], measurement = [0.8134788], per_fold = [[0.81280327, 0.8016549, 0.8153759, 0.81823415, 0.81932634]])],
#  best_report = (feature_importances = 16-element Vector{XGBoost.FeatureImportance}:
# Gain      Coverage  Frequency  Feature
# 0.1903    0.1182    0.0920     x14
# 0.1526    0.1364    0.1278     x5
# 0.0949    0.0873    0.0907     x7
# 0.0859    0.1259    0.0942     x8
# 0.0720    0.0831    0.1120     x10
# 0.0672    0.0712    0.0386     x12
# 0.0569    0.0570    0.0652     x11
# 0.0526    0.0397    0.0927     x16
# 0.0461    0.0692    0.0531     x3
# 0.0385    0.0342    0.0503     x4
# 0.0378    0.0659    0.0588     x6
# 0.0311    0.0301    0.0488     x15
# 0.0297    0.0378    0.0226     x1
# 0.0278    0.0270    0.0312     x13
# 0.0122    0.0104    0.0152     x17
# 0.0045    0.0066    0.0069     x2
# ,),
#  plotting = (parameter_names = ["min_child_weight", "subsample", "eta", "gamma", "max_depth"],
#              parameter_scales = [:linear, :linear, :linear, :linear, :linear],
#              parameter_values = Any[0.4788887538037368 0.18337042764019834 … 2.4341792897111776 10; 0.3751388464525052 0.38582137080889384 … 1.5097209748632938 6; … ; 0.2775274162753285 0.6903143954353621 … 2.0307617936560627 10; 0.27902254933487297 0.17708549650107194 … 2.4749662157836014 3],
#              measurements = [0.7472240328788757, 0.7923670411109924, 0.8315539360046387, 0.8354279398918152, 0.6662944555282593, 0.8017244338989258, 0.8382923007011414, 0.8320505023002625, 0.7954959273338318, 0.6733725666999817  …  0.7990447878837585, 0.8271317481994629, 0.6728352308273315, 0.8359107971191406, 0.7453199625015259, 0.811771035194397, 0.6653451323509216, 0.7194010615348816, 0.7765489816665649, 0.8134788274765015],),)

# %% [markdown]
# ## 4 Prediction and Submission

# %%
prediction = MLJ.predict(xg_mach, features_test_xg)
prediction = broadcast(pdf, prediction, 1.0)

sample_submission_csv.target = prediction
sample_submission_csv
# Out:
# 58069×2 DataFrame
#    Row │ client_id          target
#        │ String31           Float32
# ───────┼────────────────────────────────
#      1 │ test_Client_0      0.0304951
#      2 │ test_Client_1      0.313587
#      3 │ test_Client_10     0.0520297
#      4 │ test_Client_100    0.0198115
#      5 │ test_Client_1000   0.0405611
#      6 │ test_Client_10000  0.0668477
#      7 │ test_Client_10001  0.00568761
#      8 │ test_Client_10002  0.218913
#      9 │ test_Client_10003  0.00527934
#     10 │ test_Client_10004  0.0552941
#     11 │ test_Client_10005  0.0456482
#    ⋮   │         ⋮               ⋮
#  58060 │ test_Client_9990   0.00267613
#  58061 │ test_Client_9991   0.0165394
#  58062 │ test_Client_9992   0.0212786
#  58063 │ test_Client_9993   0.0222134
#  58064 │ test_Client_9994   0.0674716
#  58065 │ test_Client_9995   0.000845863
#  58066 │ test_Client_9996   0.0863575
#  58067 │ test_Client_9997   0.652956
#  58068 │ test_Client_9998   0.00710619
#  58069 │ test_Client_9999   0.0700079
#                       58048 rows omitted

# %%
mkdir(string("/content/drive/MyDrive/FraudDetectionAI/Submission/", Version))

CSV.write(string("/content/drive/MyDrive/FraudDetectionAI/Submission/", Version, "/submission.csv"), sample_submission_csv)
# Out:
# "/content/drive/MyDrive/FraudDetectionAI/Submission/Version_3/submission.csv"
